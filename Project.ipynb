# %%
import pandas as pd
import seaborn as sns

OriginalData=pd.read_csv('pubg - Dr. Darshan Ingle.csv')
OriginalData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 29 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Id               10000 non-null  object
#  1   groupId          10000 non-null  object
#  2   matchId          10000 non-null  object
#  3   assists          10000 non-null  int64
#  4   boosts           10000 non-null  int64
#  5   damageDealt      10000 non-null  float64
#  6   DBNOs            10000 non-null  int64
#  7   headshotKills    10000 non-null  int64
#  8   heals            10000 non-null  int64
#  9   killPlace        10000 non-null  int64
#  10  killPoints       10000 non-null  int64
#  11  kills            10000 non-null  int64
#  12  killStreaks      10000 non-null  int64
#  13  longestKill      10000 non-null  float64
#  14  matchDuration    10000 non-null  int64
#  15  matchType        10000 non-null  object
#  16  maxPlace         10000 non-null  int64
# ...

# %%
OriginalData.describe()
# Out:
#             assists        boosts   damageDealt        DBNOs  headshotKills  \
# count  10000.000000  10000.000000  10000.000000  10000.00000   10000.000000
# mean       0.234600      1.088500    129.211264      0.64400       0.221700
# std        0.575149      1.703279    167.193945      1.09562       0.577046
# min        0.000000      0.000000      0.000000      0.00000       0.000000
# 25%        0.000000      0.000000      0.000000      0.00000       0.000000
# 50%        0.000000      0.000000     83.805000      0.00000       0.000000
# 75%        0.000000      2.000000    185.325000      1.00000       0.000000
# max        7.000000     18.000000   3469.000000     11.00000      14.000000
#
#               heals     killPlace    killPoints         kills   killStreaks  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       1.354000     47.663100    506.970200      0.913400      0.543800
# ...

# %% [markdown]
# Results of our data
# Average person kills is 1
# Most kills is 35

# %% [markdown]
# The number of kills of 99% people:

# %%
ninenine=OriginalData['kills'].sort_values()
ninenine[:9900].mean()
# Out:
# 0.832929292929293

# %% [markdown]
# All columns

# %%
OriginalData.columns
# Out:
# Index(['Id', 'groupId', 'matchId', 'assists', 'boosts', 'damageDealt', 'DBNOs',
#        'headshotKills', 'heals', 'killPlace', 'killPoints', 'kills',
#        'killStreaks', 'longestKill', 'matchDuration', 'matchType', 'maxPlace',
#        'numGroups', 'rankPoints', 'revives', 'rideDistance', 'roadKills',
#        'swimDistance', 'teamKills', 'vehicleDestroys', 'walkDistance',
#        'weaponsAcquired', 'winPoints', 'winPlacePerc'],
#       dtype='object')

# %% [markdown]
# Distribution of match's duration

# %%
sns.distplot(OriginalData['matchDuration']);

# %% [markdown]
# Distribution of walk distance

# %%
sns.distplot(OriginalData['walkDistance']);

# %% [markdown]
# Match duration vs Walk distance..below each other

# %%
import  matplotlib.pyplot as plt

plt.figure()
plt.subplot(2,1,1)
sns.distplot(OriginalData['matchDuration'].sort_values(),label="Duration");
plt.legend();
plt.subplot(2,1,2)
sns.distplot(OriginalData['walkDistance'].sort_values(),label="Walk");
plt.legend();

# %% [markdown]
# Match duration vs Walk distance..side by side

# %%
plt.figure()
plt.subplot(1,2,1)
sns.distplot(OriginalData['matchDuration'].sort_values(),label="matchDuration");
plt.legend();
plt.subplot(1,2,2)
sns.distplot(OriginalData['walkDistance'].sort_values(),label="walkDistance");
plt.legend();

# %%
Temp1=pd.DataFrame(OriginalData['damageDealt'])
Temp1["kilss"]=OriginalData['kills']
print(Temp1)
Temp2=pd.DataFrame(OriginalData['maxPlace'])
Temp2['numGroups']=OriginalData['numGroups']
sns.pairplot(Temp1);
sns.pairplot(Temp2);
# Out:
#       damageDealt  kilss
# 0             0.0      0
# 1           163.2      1
# 2           278.7      2
# 3           191.9      1
# 4           100.0      0
# ...           ...    ...
# 9995        204.5      2
# 9996          0.0      0
# 9997          0.0      0
# 9998          0.0      0
# 9999          0.0      0
#
# [10000 rows x 2 columns]

# %% [markdown]
# Match types and count

# %%
OriginalData['matchType'].value_counts()
# Out:
# squad-fpp           3969
# duo-fpp             2282
# squad               1359
# solo-fpp            1234
# duo                  702
# solo                 386
# normal-squad-fpp      24
# crashfpp              13
# normal-duo-fpp        13
# normal-solo-fpp        8
# normal-squad           4
# flaretpp               3
# crashtpp               2
# flarefpp               1
# Name: matchType, dtype: int64

# %% [markdown]
# Match type vs Kill point

# %%
sns.barplot(x=OriginalData['matchType'].sort_values(),y=OriginalData['killPoints'].sort_values())
plt.xlabel("matchType")
plt.ylabel("KillPoints")
plt.xticks(rotation=70);

# %%
# Inference: Kills are more during the normal games compared to the other modes of games.

# %% [markdown]
# Match type vs Weapon aquired

# %%
sns.barplot(x=OriginalData['matchType'].sort_values(),y=OriginalData['weaponsAcquired'].sort_values())
plt.xlabel("matchType")
plt.ylabel("weaponsAcquired")
plt.xticks(rotation=70);

# %%
# Inference: weapons acquired again is more during the normal game mode.

# %% [markdown]
# Match type vs Winplaceperc

# %%
sns.boxplot(x=OriginalData['matchType'].sort_values(),y=OriginalData['winPlacePerc'].sort_values())
plt.xlabel("matchType")
plt.ylabel("winPlacePerc")
plt.xticks(rotation=70);

# %%
#Inference: winplaceperc is more during the normal duo fpp mode.

# %% [markdown]
# Match type vs Match duration

# %%
sns.boxplot(x=OriginalData['matchType'].sort_values(),y=OriginalData['matchDuration'].sort_values())
plt.xlabel("matchType")
plt.ylabel("matchDuration")
plt.xticks(rotation=70);

# %%
#Inference: normal squad matches are the longest.

# %% [markdown]
# Orientation to horizontal

# %%
sns.boxplot(y=OriginalData['matchType'].sort_values(),x=OriginalData['matchDuration'].sort_values());
plt.ylabel("matchType")
plt.xlabel("matchDuration")
plt.xticks(rotation=70);

# %% [markdown]
# Kill column

# %%
OriginalData["KILL"]=OriginalData['headshotKills']+OriginalData['teamKills']+OriginalData['roadKills']
OriginalData.iloc[:,25:]
# Out:
#       walkDistance  weaponsAcquired  winPoints  winPlacePerc  KILL
# 0             0.00                0       1470        0.0000     0
# 1           132.70                2       1531        0.2222     1
# 2          3591.00               10          0        0.8571     1
# 3           332.70                3          0        0.3462     0
# 4           252.70                3       1557        0.0690     0
# ...            ...              ...        ...           ...   ...
# 9995       1648.00                4       1471        0.8333     0
# 9996        897.10                6       1500        0.7174     0
# 9997        188.20                2       1434        0.2083     0
# 9998        108.10                5       1534        0.2449     0
# 9999         53.36                1          0        0.1875     0
#
# [10000 rows x 5 columns]

# %% [markdown]
# Winplaceperc roundoff

# %%
OriginalData['winPlacePerc']=round(OriginalData['winPlacePerc'],2)
OriginalData['winPlacePerc']
# Out:
# 0       0.00
# 1       0.22
# 2       0.86
# 3       0.35
# 4       0.07
#         ...
# 9995    0.83
# 9996    0.72
# 9997    0.21
# 9998    0.24
# 9999    0.19
# Name: winPlacePerc, Length: 10000, dtype: float64

# %% [markdown]
# Damage dealt

# %%
m=[]
for l in range(100):
    damage=OriginalData['damageDealt'].sample(50)
    m.append(damage.mean())
m=pd.DataFrame(m)
print("mean is:",m.mean())
sns.distplot(m);
# Out:
# mean is: 0    129.689965
# dtype: float64
